# %%
# @title Imports
import math
from itertools import chain
from collections import defaultdict

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.distributions as td
import torch.nn as nn
import torch.optim as optim
from tqdm.auto import trange

# %%
# @title モデルの定義


def timestep_embedding(timesteps, dim, max_period=1000):
    half = dim // 2
    freqs = torch.exp(
        -math.log(max_period)
        * torch.arange(start=0, end=half, dtype=torch.float32)
        / half
    ).to(device=timesteps.device)
    args = timesteps[:, None].float() * freqs[None]
    embedding = torch.cat([torch.cos(args), torch.sin(args)], dim=-1)
    if dim % 2:
        embedding = torch.cat([embedding, torch.zeros_like(embedding[:, :1])], dim=-1)
    return embedding


class FCResNet(nn.Module):
    def __init__(self, data_dim, hidden_dim, num_res_blocks):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.map = nn.Linear(data_dim, hidden_dim)
        self.res_blocks = nn.ModuleList(
            [self.build_res_block() for _ in range(num_res_blocks)]
        )

    def build_linear(self, in_features, out_features):
        linear = nn.Linear(in_features, out_features)
        return linear

    def build_res_block(self):
        hid = self.hidden_dim
        layers = []
        widths = [hid] * 4
        for i in range(len(widths) - 1):
            layers.append(self.build_linear(widths[i], widths[i + 1]))
            layers.append(nn.SiLU())
        return nn.Sequential(*layers)

    def forward(self, x):
        h = self.map(x)
        for res_block in self.res_blocks:
            h = (h + res_block(h)) / np.sqrt(2)
        return h


class ToyModel(torch.nn.Module):
    def __init__(self, data_dim=2, hidden_dim=256, time_embed_dim=128):
        super().__init__()

        self.time_embed_dim = time_embed_dim
        hid = hidden_dim

        self.t_module = nn.Sequential(
            nn.Linear(self.time_embed_dim, hid),
            nn.SiLU(),
            nn.Linear(hid, hid),
        )

        self.x_module = FCResNet(data_dim, hidden_dim, num_res_blocks=3)

        self.out_module = nn.Sequential(
            nn.Linear(hid, hid),
            nn.SiLU(),
            nn.Linear(hid, data_dim),
        )

    def forward(self, t, x):
        t = t.squeeze()
        if t.dim() == 0:
            t = t.repeat(x.shape[0])
        assert t.dim() == 1 and t.shape[0] == x.shape[0]

        t_emb = timestep_embedding(t, self.time_embed_dim)
        t_out = self.t_module(t_emb)
        x_out = self.x_module(x)
        out = self.out_module(x_out + t_out)
        return out

# %%
# @title utils
def flatten_dim01(x: torch.Tensor):
    return x.reshape(-1, *x.shape[2:])


def compute_div(os, xs):
    eps = torch.randn_like(xs)
    e_do_dx = torch.autograd.grad(os, xs, eps, create_graph=True, retain_graph=True)[0]
    div = e_do_dx * eps
    return div

# %%
# @title 分布の定義


class MixMultiVariateNormal:
    def __init__(self, batch_size, radius=12, num=8, sigmas=None, device="cpu"):
        arc = 2 * np.pi / num
        xs = [np.cos(arc * idx) * radius for idx in range(num)]
        ys = [np.sin(arc * idx) * radius for idx in range(num)]
        mus = [torch.tensor([x, y], device=device) for x, y in zip(xs, ys)]
        dim = len(mus[0])
        sigmas = (
            [torch.eye(dim, device=device) for _ in range(num)]
            if sigmas is None
            else sigmas
        )

        if batch_size % num != 0:
            raise ValueError("batch size must be devided by number of gaussian")
        self.num = num
        self.batch_size = batch_size
        self.dists = []
        for mu, sigma in zip(mus, sigmas):
            dist = td.multivariate_normal.MultivariateNormal(mu, sigma)
            dist._unbroadcasted_scale_tril = dist._unbroadcasted_scale_tril.double()
            self.dists.append(dist)

    def log_prob(self, x):
        # assume equally-weighted
        densities = [torch.exp(dist.log_prob(x.double())) for dist in self.dists]
        return torch.log(sum(densities) / len(self.dists))

    def sample(self, n=None):
        n = self.batch_size if n is None else n
        ind_sample = n / self.num
        samples = [dist.sample([int(ind_sample)]) for dist in self.dists]
        samples = torch.cat(samples, dim=0)
        return samples.float()

    def sample_n(self, n):
        ind_sample = n / self.num
        samples = [dist.sample([int(ind_sample)]) for dist in self.dists]
        samples = torch.cat(samples, dim=0)
        return samples.float()

# %%
# @title SDEの定義


class Policy:
    def __init__(self, p_data, p_prior, device, t0=1e-3, T=1, interval=100):
        self.p_data = p_data
        self.p_prior = p_prior
        self.device = device

        self.t0 = t0
        self.T = T
        self.interval = interval
        self.ts = torch.linspace(t0, T, interval, device=device)
        self.dt = T / interval

        self.u_phi = ToyModel().to(device)
        self.s_theta = ToyModel().to(device)

        self.opt = optim.AdamW(
            chain(self.u_phi.parameters(), self.s_theta.parameters()), lr=1e-4
        )

    def forward_step(self, t, x, is_train=False):
        pass

    def backward_step(self, t, x):
        pass

    def make_train(self):
        self.u_phi.train()
        self.s_theta.train()
        for p in chain(self.u_phi.parameters(), self.s_theta.parameters()):
            p.requires_grad = True

    def make_eval(self):
        self.u_phi.eval()
        self.s_theta.eval()
        for p in chain(self.u_phi.parameters(), self.s_theta.parameters()):
            p.requires_grad = False

    def sample_traj(self):
        x = self.p_data.sample().to(self.device)
        xs = torch.zeros(x.shape[0], len(self.ts), x.shape[1], device=self.device)
        us = torch.zeros_like(xs)

        for i, t in enumerate(self.ts):
            x, u = self.forward_step(t, x, is_train=True)
            xs[:, i] = x
            us[:, i] = u
        x_term = x
        return xs, us, x_term

    def train(self, num_iter):
        self.make_train()
        loss_dict = defaultdict(list)
        pbar = trange(num_iter)
        for it in pbar:
            self.opt.zero_grad()
            loss, output_dict = self.compute_loss()
            loss.backward()
            self.opt.step()
            pbar.set_postfix(loss=loss.item(), **output_dict)
            if (it + 1) % 2000 == 0:
                self.sample_plot()
            for k, v in output_dict.items():
                loss_dict[k].append(v)

        plt.figure(figsize=(8, 6))
        for k, v in loss_dict.items():
            plt.plot(range(1, len(v) + 1), v, label=k)
        plt.legend()
        plt.grid()
        plt.xlabel("iteration")
        plt.ylabel("Loss")
        plt.show()

        for k, v in loss_dict.items():
            plt.plot(range(1, len(v) + 1), v)
            plt.grid()
            plt.xlabel("iteration")
            plt.ylabel(f"Loss: {k}")
            plt.show()

    @torch.no_grad()
    def sample_plot(self, out_path=None, n=2000):
        self.make_eval()
        x_data = self.p_data.sample_n(n).to(self.device)
        x = x_data
        print("Generate forward direction")
        for t in self.ts:
            x = self.forward_step(t, x)
        x_T = x.detach().cpu().numpy()

        x_prior = self.p_prior.sample_n(n).to(self.device)
        x = x_prior
        print("Generate backward direction")
        for t in self.ts:
            x = self.backward_step(t, x)
        x_0 = x.detach().cpu().numpy()

        x_data = x_data.detach().cpu().numpy()
        x_prior = x_prior.detach().cpu().numpy()

        _, axes = plt.subplots(2, 3, figsize=(16, 10))
        axes[0, 0].plot(x_data[:, 0], x_data[:, 1], "o")
        axes[0, 0].set_title("p_data")
        axes[0, 1].plot(x_T[:, 0], x_T[:, 1], "o")
        axes[0, 1].set_title("p_T")
        axes[0, 2].plot(x_prior[:, 0], x_prior[:, 1], "o")
        axes[0, 2].set_title("p_prior")

        axes[1, 0].plot(x_prior[:, 0], x_prior[:, 1], "o")
        axes[1, 0].set_title("p_prior")
        axes[1, 1].plot(x_0[:, 0], x_0[:, 1], "o")
        axes[1, 1].set_title("p_0")
        axes[1, 2].plot(x_data[:, 0], x_data[:, 1], "o")
        axes[1, 2].set_title("p_data")
        for i in range(2):
            for j in range(3):
                axes[i, j].set_xlim(-20, 20)
                axes[i, j].set_ylim(-20, 20)
        if out_path is not None:
            plt.savefig(out_path)
        plt.show()
        self.make_train()

# %%
# @title common

batch_size = 80
num_iter = 10000

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

p_data = MixMultiVariateNormal(batch_size, radius=12, num=8, device=device)
p_prior = MixMultiVariateNormal(batch_size, radius=6, num=2, device=device)

# %%
x_data = p_data.sample(2000).cpu().numpy()
x_prior = p_prior.sample(2000).cpu().numpy()

_, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].plot(x_data[:, 0], x_data[:, 1], "o")
axes[0].set_title("p_data")
axes[1].plot(x_prior[:, 0], x_prior[:, 1], "o")
axes[1].set_title("p_prior")
for i in range(2):
    axes[i].set_xlim(-20, 20)
    axes[i].set_ylim(-20, 20)
plt.show()
plt.close()

# %% [markdown]
# ### Stochastic optimal control
#
# $g(t) = 1.0$
#
# - Forward
# $$
# d X_t = u_\phi(t, X_t) dt + d W_t, \quad X_0 \sim \mu
# $$
#
# - Backward
# $$
# d X_t = \mathbf{s}_\theta(t, X_t) dt + d W_t, \quad X_T \sim \pi
# $$
#
# Loss
#
# $$
# \min_{\phi, \theta} \, \mathbb{E}_X \left[ -\log \pi(X_T) + \int_0^T \left( \frac{1}{2} ||\mathbf{u}_\phi(t, X_t) + \mathbf{s}_\theta(t, X_t)||^2 + \nabla \cdot \mathbf{s}_\theta(t, X_t) \right) \right]
# $$

# %%
# @title


class SOC(Policy):
    def forward_step(self, t, x, is_train=False):
        u = self.u_phi(t, x)
        dX = u * self.dt + torch.randn_like(x) * np.sqrt(self.dt)
        return (x + dX, u) if is_train else x + dX

    def backward_step(self, t, x):
        s = self.s_theta(t, x)
        dX = s * self.dt + torch.randn_like(x) * np.sqrt(self.dt)
        return x + dX

    def compute_loss(self):
        x, u, x_term = self.sample_traj()
        t = self.ts.repeat(batch_size)
        x = flatten_dim01(x)
        u = flatten_dim01(u)
        s = self.s_theta(t, x)

        integrand = 0.5 * (u + s) ** 2 + compute_div(s, x)
        E_integrand = integrand.reshape(
            x_term.shape[0], self.interval, x_term.shape[-1]
        ).mean(dim=0)
        loss_prior = -self.p_prior.log_prob(x_term).mean()
        loss_running = (E_integrand * self.dt).sum()
        loss = loss_prior + loss_running
        output_dict = dict(
            prior=loss_prior.item(),
            running=loss_running.item(),
        )
        return loss, output_dict


SOC(p_data, p_prior, device).train(num_iter)
# Out:
#  20%|█▉        | 1999/10000 [07:59<32:44,  4.07it/s, loss=5.41, prior=3.62, running=1.79]
# Generate forward direction
# Generate backward direction
#  40%|███▉      | 3999/10000 [16:01<24:27,  4.09it/s, loss=5.13, prior=3.51, running=1.62]
# Generate forward direction
# Generate backward direction
#  60%|█████▉    | 5999/10000 [24:04<15:58,  4.18it/s, loss=5.05, prior=3.72, running=1.33]
# Generate forward direction
# Generate backward direction
#  80%|███████▉  | 7999/10000 [32:02<08:09,  4.09it/s, loss=5.04, prior=3.52, running=1.52]
# Generate forward direction
# Generate backward direction
# 100%|█████████▉| 9999/10000 [39:52<00:00,  4.38it/s, loss=5.06, prior=3.59, running=1.46]
# Generate forward direction
# Generate backward direction
# 100%|██████████| 10000/10000 [39:52<00:00,  4.18it/s, loss=5.06, prior=3.59, running=1.46]

# %%
# @title


class DOC(Policy):
    def forward_step(self, t, x, is_train=False):
        u = self.u_phi(t, x)
        dX = u * self.dt
        return (x + dX, u) if is_train else x + dX

    def backward_step(self, t, x):
        s = self.s_theta(t, x)
        dX = s * self.dt
        return x + dX

    def compute_loss(self):
        x, u, x_term = self.sample_traj()
        t = self.ts.repeat(batch_size)
        x = flatten_dim01(x)
        u = flatten_dim01(u)
        s = self.s_theta(t, x)

        integrand = 0.5 * (u + s).pow(2)
        E_integrand = integrand.reshape(
            x_term.shape[0], self.interval, x_term.shape[-1]
        ).mean(dim=0)
        loss_prior = -self.p_prior.log_prob(x_term).mean()
        loss_running = (E_integrand * self.dt).sum()
        loss = loss_prior + loss_running
        output_dict = dict(
            prior=loss_prior.item(),
            running=loss_running.item(),
        )
        return loss, output_dict


DOC(p_data, p_prior, device).train(num_iter)
# Out:
#   0%|          | 2/10000 [00:00<33:21,  4.99it/s, loss=49.6, prior=49.4, running=0.188]
#  20%|█▉        | 1999/10000 [07:02<28:22,  4.70it/s, loss=2.54, prior=2.54, running=0.00309]
# Generate forward direction
# Generate backward direction
#  40%|███▉      | 3999/10000 [14:09<21:33,  4.64it/s, loss=2.53, prior=2.53, running=0.000587]
# Generate forward direction
# Generate backward direction
#  60%|█████▉    | 5999/10000 [21:15<14:52,  4.48it/s, loss=2.53, prior=2.53, running=0.00138]
# Generate forward direction
# Generate backward direction
#  80%|███████▉  | 7999/10000 [28:21<07:02,  4.74it/s, loss=2.58, prior=2.53, running=0.0509]
# Generate forward direction
# Generate backward direction
# 100%|█████████▉| 9999/10000 [35:27<00:00,  4.68it/s, loss=2.54, prior=2.53, running=0.00545]
# Generate forward direction
# Generate backward direction
# 100%|██████████| 10000/10000 [35:28<00:00,  4.70it/s, loss=2.54, prior=2.53, running=0.00545]

# %%
# @title


class DOC(Policy):
    def forward_step(self, t, x, is_train=False):
        u = self.u_phi(t, x)
        dX = u * self.dt
        return (x + dX, u) if is_train else x + dX

    def backward_step(self, t, x):
        s = self.s_theta(t, x)
        dX = s * self.dt
        return x + dX

    def compute_loss(self):
        x, u, x_term = self.sample_traj()
        t = self.ts.repeat(batch_size)
        x = flatten_dim01(x)
        u = self.u_phi(t, x)
        s = self.s_theta(t, x)

        integrand = 0.5 * (u + s).pow(2)
        E_integrand = integrand.reshape(
            x_term.shape[0], self.interval, x_term.shape[-1]
        ).mean(dim=0)
        loss_prior = -self.p_prior.log_prob(x_term).mean()
        loss_running = (E_integrand * self.dt).sum()
        scale = loss_prior.item() / loss_running.item()
        loss = loss_prior + loss_running * scale
        output_dict = dict(
            prior=loss_prior.item(),
            running=loss_running.item(),
            running_scale=loss_running.item() * scale,
        )
        return loss, output_dict


DOC(p_data, p_prior, device).train(num_iter)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#   6%|▋         | 634/10000 [02:15<33:15,  4.69it/s, loss=90, prior=45, running=0.000278, running_scale=45]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 38
#      30         output_dict = dict(
#      31             prior=loss_prior.item(),
#      32             running=loss_running.item(),
#      33             running_scale=loss_running.item() * scale,
#      34         )
#      35         return loss, output_dict
# ---> 38 DOC(p_data, p_prior, device).train(num_iter)
#
# Cell In[23], line 60, in Policy.train(self, num_iter)
#      58 self.opt.zero_grad()
#      59 loss, output_dict = self.compute_loss()
# ---> 60 loss.backward()
#      61 self.opt.step()
#      62 pbar.set_postfix(loss=loss.item(), **output_dict)
#
# File ~/work/sbsde/.venv/lib/python3.10/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/work/sbsde/.venv/lib/python3.10/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
# @title


class SOC(Policy):
    def forward_step(self, t, x, is_train=False):
        u = self.u_phi(t, x)
        dX = u * self.dt + torch.randn_like(x) * np.sqrt(self.dt)
        return (x + dX, u) if is_train else x + dX

    def backward_step(self, t, x):
        s = self.s_theta(t, x)
        dX = s * self.dt + torch.randn_like(x) * np.sqrt(self.dt)
        return x + dX

    def compute_loss(self):
        x, u, x_term = self.sample_traj()
        t = self.ts.repeat(batch_size)
        x = flatten_dim01(x)
        u = flatten_dim01(u)
        s = self.s_theta(t, x)

        integrand = 0.5 * (u + s) ** 2 + compute_div(s, x)
        E_integrand = integrand.reshape(
            x_term.shape[0], self.interval, x_term.shape[-1]
        ).mean(dim=0)
        loss_prior = -self.p_prior.log_prob(x_term).mean()
        loss_running = (E_integrand * self.dt).sum()
        loss = loss_prior + loss_running
        output_dict = dict(
            prior=loss_prior.item(),
            running=loss_running.item(),
        )
        return loss, output_dict


SOC(p_data, p_prior, device).train(num_iter)
